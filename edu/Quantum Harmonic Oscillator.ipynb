# %% [markdown]
# https://ocw.mit.edu/courses/nuclear-engineering/22-51-quantum-theory-of-radiation-interactions-fall-2012/lecture-notes/MIT22_51F12_Ch9.pdf
#
# https://www2.ph.ed.ac.uk/~ldeldebb/docs/QM/lect12.pdf
#
# https://www.classe.cornell.edu/~dlr/teaching/p6572/ps2sols.pdf
#
# https://web.mst.edu/~parris/QuantumTwo/Class_Notes/HarmonicOscillator.pdf

# %% [markdown]
# Enery Eigenasis
#
# Any observable operators in their own eigenbasis are diagonal, the diagonal entries being the eigenvalues. $<H>_{mn}=<\psi_m|H|\psi_n>=<\psi_m|E_n|\psi_n>=E_n \delta_{m,n}$.
#
# The second quantization expression in this form is in the energy eigenbasis. This is readily seen from: $<\psi_m|H|\psi_n>=<\psi_m|\hbar \omega (a^\dagger a + \frac{1}{2})|\psi_n>=\delta_{m,n} \hbar \omega (n+\frac{1}{2})= \delta_{m,n} E_n$

# %% [markdown]
# # Harmonic Oscillator
#
# #### Classical
#
# $$f''=-\omega^2 f$$
#
# #### Quantum
#
# $$f[a,a^\dagger]=I$$

# %% [markdown]
# # Quantum Harmonic Oscillator
#
# ### Hamiltonian
#
# We consider the one dimensional SHO, which has a potential of the form $V(x) = \frac{k}{2} x^2$.
#
# $$H= \frac{\hat{p}^2}{2m} + \frac{k}{2} \hat{x}^2$$
#
# We are working in the position basis. The usual substitutions follow: $X->x$, $P->-i\hbar \frac{d}{dx}$, $|E>->\psi_E(x)$.
#
# $$H= -\frac{\hbar^2}{2m}\frac{\partial^2}{\partial^2 x} + \frac{k}{2} \hat{x}^2$$
#
# And it is common to express the spring constant as $k=m \omega^2$.
#
# $$H= -\frac{\hbar^2}{2m}\frac{\partial^2}{\partial^2 x} + \frac{m \omega^2}{2} \hat{x}^2$$
#
# ### Commutations
#
# $$[x,p]=i \hbar$$
# $$[x,p^2]=2i \hbar p$$
# $$[x^2,p^2]=4i\hbar p x - 2\hbar^2 I$$
#
# Note that the canonical commutation relation $[x,p]=i \hbar$ is what brings about the zero point fluctuations in the system (and the nonzero energy ground state).
#
# ##### -Hamiltonian
#
# $$[x,H]=[x,\frac{p^2}{2m}]=i \hbar \frac{p}{m}$$
#
# ##### -Translation
#
# Translation operator $\hat{T}(l)=e^{-i \frac{pl}{\hbar}}$. Generates shifts in position.
#
# $$[x,T(l)]=l T(l)$$
#
# Boost operator $\hat{K}(o)=e^{i \frac{xo}{\hbar}}$. Generates shifts in momentum.
#
# $$[x,T(l)]=l T(l)$$
#
# ##### -3D Case
#
# $$[x_i,p_j]=i \hbar \delta_{i,j}$$
# $$[x_i,x_j]=0$$
# $$[p_i,p_j]=0$$
#
#
# ### Eigenfunctions
#
# $$\psi_n(x) = \frac{1}{(2^n n! \sqrt{\pi})^{1/2}} H_n(x) e^{-x^2 /2}$$
#
# Where the H function is the nth Hermite Polynomial. The Hermite polynomials have a useful recursion relation that can be found in Shankar-7.3.24.
#
# ### Eigenvalues
#
# $$E_n = \hbar \omega (n+\frac{1}{2})$$
#
# We can consider the energy eigenvalues in terms of n quanta. We pretend there exist fictitious particles, each with energy $\hbar \omega$, such that an increase in energy corresponds to increasing the number of quanta.
#
# ### Expectation Values
#
# $$<n|x|n>=<x>=<p>=0$$
# $$<x^2>=\frac{3 \hbar}{2m \omega}$$
# $$<p^2>=\frac{3m \omega \hbar}{2}$$

# %% [markdown]
# # 2nd Quantization
#
# ### Hamiltonian
#
# $$H= \hbar \omega(\hat{a}^\dagger \hat{a} +\frac{1}{2})$$
#
# The second quantization expression in this form is in the energy eigenbasis, as opposed to the x basis above. It is diagonalized in terms of the Number operator ($\hat{N}=\hat{a}^\dagger \hat{a}$) where N has the eigenvalues {1,2,...}, and each eigenvalue corresponds to a stae $|n>$.
#
# ### Ladder Operators
#
# Introducing the raising $a^\dagger$ and lowering $a$ operators.
#
# $$a= \sqrt{\frac{m \omega}{2 \hbar}}(\hat{x} + \frac{i}{m \omega} \hat{p})$$
# $$a^\dagger= \sqrt{\frac{m \omega}{2 \hbar}}(\hat{x} - \frac{i}{m \omega} \hat{p})$$
#
# $$a^\dagger |n> = \sqrt{n+1}|n+1>$$
# $$a |n> = \sqrt{n}|n-1>$$
#
# Number operator N (counts quanta):
#
# $$N=a^\dagger a$$
# $$N|n>=n|n>$$
#
# ### 2nd Quantization Commutations
#
# $$[a,a^\dagger]=I$$
# $$[a,(a^\dagger)^n]=n(a^\dagger)^{n-1}$$
# $$[N,a^\dagger]=a^\dagger$$
# $$[N,a]=-a$$
# $$[H,a]=-\hbar \omega a$$
# $$[H,a^\dagger]=\hbar \omega a^\dagger$$
#
# ### Relations
#
# We can express all normalized eigenvectors $|n>$ in terms of the ground state $|0>$.
#
# $$|n>= \frac{(a^\dagger)^n}{(n!)^1/2} |0>$$

# %% [markdown]
# # Relevant Part
#
# $$H= \hbar \omega(N +\frac{1}{2})$$
#
# In the energy basis, N and H are diagonal while $a, a^\dagger, q, p$ connect each energy eigenstate to the states immediatly above or below it.
#
# $$N ->
# \begin{pmatrix}
# 0 & 0 & 0 & ...\\
# 0 & 1 & 0 & ...\\
# 0 & 0 & 2 & ...
# \end{pmatrix}$$
#
# $$H ->
# \hbar \omega
# \begin{pmatrix}
# 1/2 & 0 & 0 & ...\\
# 0 & 3/2 & 0 & ...\\
# 0 & 0 & 5/2 & ...
# \end{pmatrix}$$
#
# $$a ->
# \begin{pmatrix}
# 0 & \sqrt{1} & 0 & 0 & ...\\
# 0 & 0 & \sqrt{2} & 0 & ...\\
# 0 & 0 & 0 & \sqrt{3} & ...
# \end{pmatrix}$$
#
# $$a^\dagger ->
# \begin{pmatrix}
# 0 & 0 & 0 & ...\\
# \sqrt{1} & 0 & 0 & ...\\
# 0 & \sqrt{2} & 0 & ...\\
# 0 & 0 & \sqrt{3} & ...
# \end{pmatrix}$$
#
# $$x ->
# \begin{pmatrix}
# 0 & \sqrt{1/2} & 0 & ...\\
# \sqrt{1/2} & 0 & \sqrt{2/2} & ...\\
# 0 & \sqrt{2/2} & 0 & ...\\
# 0 & 0 & \sqrt{3/2} & ...
# \end{pmatrix}$$
#
# $$p ->
# \begin{pmatrix}
# 0 & -i\sqrt{1/2} & 0 & ...\\
# i\sqrt{1/2} & 0 & -i\sqrt{2/2} & ...\\
# 0 & i\sqrt{2/2} & 0 & ...\\
# 0 & 0 & i\sqrt{3/2} & ...
# \end{pmatrix}$$

# %%
using Plots
using LinearAlgebra

# function Pn(n::Int64, x)
#     return wavefcn_n(n,x) .* conj( wavefcn_n(n,x) )
# end

function 𝜓_n(n::Int64, x)
    prefactor = 1/(2^n * factorial(n) * sqrt(pi))^(1/2)
    return prefactor .* hermite(n, x) .* exp.(-x .* x /2)
end

function hermite(n::Int64, x)
    if n==0
        return ones(length(x))
    elseif n==1
        return 2 .*x
    else
        return 2 .* x .* hermite(n-1, x) - 2*(n-1) .* hermite(n-2, x)
    end
end
# Out:
# hermite (generic function with 1 method)

# %%
function time_evolve(state)
    U = e .^ (im * H)
end

# %%
# f(x) is the shape of your wavefunction at t=0
function construct_wvfcn( f_of_x )
    for (i, x_i) in enumerate(x)
        
    end
end

# %%
function mixed_state(c_list, x)
    psi = zeros( length(x) )
    for (n, c) in enumerate(c_list)
        psi += c .* 𝜓_n(n, x)
    end
    return psi
end
# Out:
# mixed_state (generic function with 1 method)

# %%
x = range(-6, stop=6, length=500)
cs = [0, -1, 0, -1, 0, 1]
psi = mixed_state(cs, x)
# Out:
# 500-element Vector{Float64}:
#  0.00011567248834696268
#  0.0001300291093990157
#  0.00014606277700276806
#  0.00016395560344125475
#  0.00018390773483660907
#  0.0002061389257295928
#  0.00023089022643456994
#  0.00025842578840560903
#  0.0002890347927482693
#  0.0003230335068544642
#  0.0003607674739180639
#  0.000402613839799123
#  0.0004489838213375419
#  ⋮
#  0.00040261383979912327
#  0.0003607674739180639
#  0.0003230335068544644
#  0.0002890347927482693
#  0.0002584257884056093
#  0.00023089022643456994
#  0.000206138925729593
#  0.00018390773483660907
#  0.00016395560344125497
#  0.00014606277700276806
#  0.0001300291093990159
#  0.00011567248834696268

# %%
Plots.plot(x, psi)

# %%
dot(𝜓_n(7,x), 𝜓_n(10,x))
# Out:
# 4.974702426255653e-15

# %%
for i in 1:9
    println( dot(wavefcn_n(i,x), wavefcn_n(i,x))  )
end
# Out:
# 41.583333333333265
# 41.58333333333126
# 41.583333333284784
# 41.583333332502995
# 41.583333322305855
# 41.58333321502772
# 41.5833322802713
# 41.583325406925766
# 41.583282172902244

# %%
for i in 1:9
    println( 7^-1 * tr( Ψ_n(i,x) .* transpose(Ψ_n(i,x)) ) )
end
# Out:
# 1.77743033857424
# 1.5182217475321629
# 1.360845102970905
# 1.2510575356712748
# 1.1682829172427993
# 1.1026874675199487
# 1.048868935746418
# 1.0035669780765573
# 0.9646754097190415

# %%
pl = []
for i in 1:12
    append!(pl, dot(𝜓_n(i,x), 𝜓_n(i,x)) )
end

# %%
Plots.plot(pl)

# %%
x = range(-6, stop=6, length=500)
Plots.plot(x, Ψ_n(3,x) )

# %%
import Pkg; Pkg.add("Schrodinger")
# Out:
# The following package names could not be resolved:
#  * Schrodinger (not found in project, manifest or registry)
#
#
# Stacktrace:
#   [1] pkgerror(msg::String)
#     @ Pkg.Types /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Types.jl:55
#   [2] ensure_resolved(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; registry::Bool)
#     @ Pkg.Types /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Types.jl:866
#   [3] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform, kwargs::Base.Iterators.Pairs{Symbol, Base.TTY, Tuple{Symbol}, NamedTuple{(:io,), Tuple{Base.TTY}}})
#     @ Pkg.API /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.6/Pkg/src/API.jl:192
# ...

# %%
using Schrodinger
# Out:
# ArgumentError: Package Schrodinger not found in current path:
# - Run `import Pkg; Pkg.add("Schrodinger")` to install the Schrodinger package.
#
#
# Stacktrace:
#  [1] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:871
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094
